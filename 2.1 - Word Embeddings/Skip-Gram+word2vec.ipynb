# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
counter = Counter(int_words)
total_words = len(int_words)
t = 1e-5
p_drop = {}

for num_word, count in counter.items():
    f_w = count / total_words
    p_drop[num_word] = 1 - np.sqrt(t / f_w)

train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    r = np.random.randint(1, window_size+1)
    start = idx - r if (idx - r) > 0 else 0
    finish = idx + r
    target_words = set(words[start:idx] + words[idx+1:finish+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6567 0.1742 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5972 0.1727 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5089 0.1733 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5923 0.1729 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5144 0.1731 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5197 0.1722 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5384 0.1723 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5042 0.1726 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4640 0.1720 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4395 0.1721 sec/batch
# Nearest to than: microelectronic, homered, willem, diglossia, cholas, terrains, archduchess, survives,
# Nearest to use: adele, exchanger, mobil, authority, merisi, lies, torrential, inmarsat,
# Nearest to all: tableland, astronomers, glycolytic, hoysala, aryan, bothnia, manchuria, shortages,
# Nearest to eight: ecchi, domesticated, smelled, drusus, formant, cracked, bemba, blackhawks,
# Nearest to more: irreducibility, menor, forming, reckoning, cytosine, humanoid, calvert, socialite,
# Nearest to after: batman, entanglement, rda, powders, gip, jes, fictions, expediency,
# Nearest to used: strangle, steered, gwr, saturation, kruskal, lees, parlor, extreme,
# Nearest to are: bankhead, terrence, psr, menus, waylon, strumming, wachowski, hellenized,
# Nearest to taking: hist, biz, sassanids, undesirables, tbms, beal, henryk, spacious,
# Nearest to liberal: ironside, keir, mutton, pivotal, pedophiles, nabi, chemist, expressionists,
# Nearest to consists: republika, forested, mcguinness, sinh, planter, subkey, waited, oilfields,
# Nearest to bible: geography, nee, suvs, opry, plying, bombers, experiment, komm,
# Nearest to frac: hi, proletarian, interventional, democratically, sit, behrens, members, cebidae,
# Nearest to recorded: howlin, delays, ayurveda, thaw, lindbergh, atheistic, funnel, discussions,
# Nearest to experience: travelogue, revitalization, cosines, rupp, nusa, erasable, doubles, fusible,
# Nearest to gold: irr, rzburg, unconvincing, mee, dialectic, showdown, reordered, chondrites,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4786 0.1754 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4022 0.1728 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3021 0.1730 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2416 0.1720 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1907 0.1732 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1413 0.1726 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0989 0.1736 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0604 0.1760 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0033 0.1761 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9566 0.1764 sec/batch
# Nearest to than: microelectronic, survives, diglossia, homered, towards, highway, transition, shirts,
# Nearest to use: authority, adele, lies, grade, exchanger, defense, mobil, tangible,
# Nearest to all: astronomers, aryan, shortages, changes, morphology, tableland, nationalism, custom,
# Nearest to eight: domesticated, cm, ecchi, cracked, smelled, drusus, boomer, children,
# Nearest to more: forming, reckoning, nevertheless, irreducibility, exact, institutions, cytosine, humanoid,
# Nearest to after: batman, desire, jes, gip, rda, powders, fictions, entanglement,
# Nearest to used: extreme, steered, matters, strangle, saturation, gwr, shapes, lees,
# Nearest to are: bankhead, do, inside, eventually, terrence, psr, decided, floor,
# Nearest to taking: hist, undesirables, sassanids, reckoned, action, biz, elephants, cole,
# Nearest to liberal: ironside, keir, mutton, pivotal, pedophiles, nabi, joy, chemist,
# Nearest to consists: republika, forested, weapon, arrows, waited, take, apart, rabbits,
# Nearest to bible: geography, experiment, nee, usually, discoveries, calculation, europe, celts,
# Nearest to frac: hi, proletarian, rc, members, sit, third, definitions, democratically,
# Nearest to recorded: delays, traditional, discussions, particular, howlin, ayurveda, atheistic, entrant,
# Nearest to experience: revitalization, engineering, peer, utilized, parish, shapes, rupp, travelogue,
# Nearest to gold: irr, load, radio, unconvincing, floor, expecting, showdown, dialectic,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9192 0.1798 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8894 0.1771 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8671 0.1770 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8569 0.1775 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8113 0.1752 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8064 0.1750 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7902 0.1776 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7762 0.1783 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7804 0.1768 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7691 0.1753 sec/batch
# Nearest to than: microelectronic, terrains, diglossia, reeves, homered, survives, reintroduced, transition,
# Nearest to use: authority, adele, mobil, exchanger, lies, defense, tangible, grade,
# Nearest to all: astronomers, aryan, efficiently, forcibly, custom, bothnia, shortages, morphology,
# Nearest to eight: domesticated, boomer, ecchi, martin, cm, smelled, shalom, formant,
# Nearest to more: forming, irreducibility, nevertheless, reckoning, exact, humanoid, menor, institutions,
# Nearest to after: batman, entanglement, jes, powders, cater, fictions, parade, gip,
# Nearest to used: steered, strangle, extreme, eden, matters, gwr, lees, saturation,
# Nearest to are: terrence, psr, bankhead, ball, eventually, wachowski, do, decided,
# Nearest to taking: hist, undesirables, sassanids, action, reckoned, elephants, biz, cole,
# Nearest to liberal: mutton, ironside, keir, pivotal, share, chemist, joy, contend,
# Nearest to consists: republika, forested, arrows, inscriptions, netscape, mcguinness, ridden, subkey,
# Nearest to bible: geography, nee, europe, experiment, encyclopedia, discoveries, celts, usually,
# Nearest to frac: hi, definitions, third, rc, sit, democratically, proletarian, members,
# Nearest to recorded: discussions, delays, howlin, traditional, interpretations, lindbergh, ayurveda, particular,
# Nearest to experience: utilized, revitalization, peer, travelogue, restriction, parish, engineering, doubles,
# Nearest to gold: irr, load, radio, showdown, unconvincing, rzburg, mee, dialectic,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7983 0.1790 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7715 0.1760 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7035 0.1749 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7020 0.1748 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7358 0.1795 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6961 0.1766 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7261 0.1767 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7275 0.1751 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6774 0.1750 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6394 0.1751 sec/batch
# Nearest to than: microelectronic, terrains, reeves, diglossia, solves, padding, reintroduced, homered,
# Nearest to use: adele, authority, mobil, tangible, jubilant, gambling, fetishes, defense,
# Nearest to all: astronomers, aryan, manchuria, tableland, efficiently, bothnia, forcibly, glycolytic,
# Nearest to eight: domesticated, martin, boomer, shalom, ecchi, five, one, smelled,
# Nearest to more: irreducibility, forming, nevertheless, reckoning, monmouth, exact, socialite, humanoid,
# Nearest to after: batman, jes, entanglement, cater, powders, fictions, parade, expelled,
# Nearest to used: strangle, steered, lees, extreme, kruskal, trafficking, gwr, eden,
# Nearest to are: terrence, psr, ball, inside, bankhead, wachowski, popes, do,
# Nearest to taking: hist, undesirables, sassanids, reckoned, action, adhering, biz, repealed,
# Nearest to liberal: ironside, pivotal, keir, mutton, chemist, pedophiles, joy, share,
# Nearest to consists: republika, forested, arrows, mcguinness, eh, dirt, netscape, inscriptions,
# Nearest to bible: geography, nee, encyclopedia, ter, bombers, celts, leeching, europe,
# Nearest to frac: hi, definitions, rc, proletarian, third, democratically, sit, interventional,
# Nearest to recorded: discussions, ayurveda, howlin, lindbergh, delays, thaw, traditional, atheistic,
# Nearest to experience: travelogue, revitalization, restriction, utilized, peer, cosines, rupp, osteichthyes,
# Nearest to gold: irr, showdown, rzburg, load, unconvincing, mee, radio, thummim,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6859 0.1795 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6612 0.1771 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6151 0.1756 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6376 0.1756 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6155 0.1756 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6424 0.1760 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5837 0.1288 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5416 0.1766 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5396 0.1767 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5064 0.1756 sec/batch
# Nearest to than: microelectronic, terrains, diglossia, reeves, solves, scolded, padding, clones,
# Nearest to use: mobil, adele, computer, tangible, authority, jubilant, tends, uses,
# Nearest to all: astronomers, tableland, aryan, efficiently, manchuria, bothnia, tripled, glycolytic,
# Nearest to eight: martin, one, writer, five, boomer, d, domesticated, shalom,
# Nearest to more: forming, irreducibility, nevertheless, exact, menor, reckoning, shoals, monmouth,
# Nearest to after: batman, expelled, parade, jes, bloodshed, korn, cater, fictions,
# Nearest to used: strangle, extreme, steered, squid, sleeker, kruskal, lees, gwr,
# Nearest to are: proportional, terrence, inside, wachowski, implies, do, bankhead, debugging,
# Nearest to taking: hist, undesirables, sassanids, reckoned, action, moeller, adhering, tbms,
# Nearest to liberal: ironside, keir, pivotal, mutton, pedophiles, chemist, joy, nabi,
# Nearest to consists: republika, forested, mcguinness, subkey, netscape, eh, possessors, dirt,
# Nearest to bible: geography, nee, encyclopedia, leeching, celts, ter, reveals, bombers,
# Nearest to frac: hi, definitions, interventional, functions, third, rc, stela, proletarian,
# Nearest to recorded: discussions, ayurveda, delays, lindbergh, howlin, thaw, traditional, atheistic,
# Nearest to experience: travelogue, cosines, revitalization, restriction, peer, utilized, archdiocese, osteichthyes,
# Nearest to gold: irr, rzburg, showdown, load, mee, radio, unconvincing, aachen,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5231 0.1796 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5168 0.1792 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4560 0.1783 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5092 0.1770 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5106 0.1791 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4862 0.1777 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4595 0.1752 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4006 0.1756 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4395 0.1763 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4691 0.1764 sec/batch
# Nearest to than: microelectronic, diglossia, solves, reeves, terrains, padding, transition, compressing,
# Nearest to use: computer, mobil, adele, tangible, jubilant, uses, tends, customized,
# Nearest to all: astronomers, efficiently, aryan, tableland, bothnia, tripled, forcibly, manchuria,
# Nearest to eight: domesticated, martin, ecchi, five, shalom, cm, adolphe, smelled,
# Nearest to more: forming, irreducibility, exact, menor, nevertheless, reckoning, shoals, plants,
# Nearest to after: batman, bloodshed, expelled, parade, jes, korn, popped, desire,
# Nearest to used: strangle, sleeker, extreme, shapes, steered, squid, nouns, lees,
# Nearest to are: inside, implies, proportional, bankhead, and, do, mukti, vary,
# Nearest to taking: sassanids, hist, undesirables, tbms, action, words, moeller, reckoned,
# Nearest to liberal: keir, ironside, pivotal, mutton, pedophiles, illyria, wilmot, nabi,
# Nearest to consists: forested, republika, netscape, mcguinness, subkey, areas, arrows, dirt,
# Nearest to bible: geography, encyclopedia, celts, nee, leeching, provost, zandvoort, ter,
# Nearest to frac: definitions, functions, cdot, hi, interventional, undefined, rc, stela,
# Nearest to recorded: discussions, howlin, delays, ayurveda, thaw, lindbergh, atheistic, traditional,
# Nearest to experience: cosines, travelogue, restriction, peer, revitalization, utilized, archdiocese, osteichthyes,
# Nearest to gold: irr, rzburg, showdown, load, satya, trapdoor, aachen, unconvincing,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4607 0.1784 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4121 0.1754 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4270 0.1756 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3961 0.1754 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4087 0.1747 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4567 0.1760 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3859 0.1756 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3835 0.1745 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4089 0.1756 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3775 0.1773 sec/batch
# Nearest to than: microelectronic, diglossia, solves, reeves, padding, transition, terrains, fundamento,
# Nearest to use: computer, tangible, customized, mobil, adele, jubilant, fetishes, uses,
# Nearest to all: astronomers, efficiently, tableland, bothnia, aryan, tripled, forcibly, glycolytic,
# Nearest to eight: martin, five, ecchi, one, domesticated, boomer, shalom, freedesktop,
# Nearest to more: irreducibility, forming, reckoning, nevertheless, tz, sanshiro, menor, exact,
# Nearest to after: batman, expelled, parade, bloodshed, desire, jes, sanfl, korn,
# Nearest to used: strangle, sleeker, steered, shapes, extreme, squid, pollinator, gwr,
# Nearest to are: implies, bankhead, inside, proportional, do, observables, floor, menus,
# Nearest to taking: sassanids, undesirables, hist, action, tbms, reckoned, adhering, words,
# Nearest to liberal: keir, pivotal, ironside, pedophiles, illyria, share, nabi, mutton,
# Nearest to consists: forested, republika, subkey, netscape, areas, marginal, mcguinness, widest,
# Nearest to bible: encyclopedia, geography, celts, ter, nee, zandvoort, tanakh, provost,
# Nearest to frac: cdot, functions, definitions, undefined, sum, interventional, hi, rc,
# Nearest to recorded: discussions, lindbergh, thaw, howlin, guitarist, music, ayurveda, atheistic,
# Nearest to experience: travelogue, cosines, restriction, revitalization, archdiocese, peer, osteichthyes, utilized,
# Nearest to gold: irr, showdown, rzburg, load, trapdoor, satya, floor, bormann,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3893 0.1785 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4033 0.1762 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3584 0.1746 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3874 0.1756 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3995 0.1748 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3875 0.1753 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4016 0.1751 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3619 0.1755 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3403 0.1754 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3394 0.1751 sec/batch
# Nearest to than: microelectronic, solves, diglossia, padding, tines, fundamento, stereocenter, scolded,
# Nearest to use: tangible, computer, conformance, customized, impenetrable, mobil, uracil, fetishes,
# Nearest to all: astronomers, efficiently, tableland, glycolytic, bothnia, hutu, aryan, burrus,
# Nearest to eight: ecchi, five, one, smelled, freedesktop, domesticated, seven, four,
# Nearest to more: reckoning, forming, irreducibility, menor, sanshiro, nevertheless, tz, cytosine,
# Nearest to after: batman, expelled, bloodshed, sanfl, parade, desire, intervene, popped,
# Nearest to used: strangle, steered, sleeker, gwr, squid, tio, pollinator, cocktails,
# Nearest to are: implies, and, observables, hellenized, do, nomadic, consider, psr,
# Nearest to taking: undesirables, sassanids, hist, action, tbms, adhering, repealed, moeller,
# Nearest to liberal: keir, pivotal, ironside, pedophiles, illyria, share, hurdles, crippling,
# Nearest to consists: forested, widest, republika, situated, marginal, subkey, mcguinness, netscape,
# Nearest to bible: encyclopedia, geography, tanakh, liturgical, celts, ter, priestess, zandvoort,
# Nearest to frac: cdot, functions, undefined, definitions, sum, hi, interventional, e,
# Nearest to recorded: discussions, howlin, thaw, ayurveda, lindbergh, guitarist, music, tyndall,
# Nearest to experience: restriction, revitalization, travelogue, cosines, peer, scientifically, archdiocese, osteichthyes,
# Nearest to gold: irr, trapdoor, load, satya, showdown, finely, rzburg, aachen,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3446 0.1789 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3020 0.1773 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3641 0.1759 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3773 0.1751 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3868 0.1750 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2909 0.1751 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2915 0.1737 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3582 0.1756 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2203 0.1755 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3129 0.1765 sec/batch
# Nearest to than: microelectronic, diglossia, tines, padding, solves, fundamento, scolded, stereocenter,
# Nearest to use: computer, customized, tangible, mobil, conformance, telephony, impenetrable, optimized,
# Nearest to all: astronomers, efficiently, tableland, bothnia, glycolytic, hutu, aryan, burrus,
# Nearest to eight: one, five, seven, ecchi, four, six, martin, freedesktop,
# Nearest to more: reckoning, forming, irreducibility, shoals, menor, humanoid, compactly, nevertheless,
# Nearest to after: batman, bloodshed, expelled, parade, sanfl, desire, intervene, hallmark,
# Nearest to used: strangle, steered, sleeker, pollinator, shackles, tio, gwr, coined,
# Nearest to are: implies, nomadic, hellenized, consider, observables, erosion, scantily, psr,
# Nearest to taking: sassanids, undesirables, hist, adhering, tbms, moeller, action, reckoned,
# Nearest to liberal: pedophiles, keir, ironside, pivotal, illyria, contend, delight, share,
# Nearest to consists: forested, marginal, bicameral, republika, situated, possessors, subkey, widest,
# Nearest to bible: encyclopedia, tanakh, geography, liturgical, alexandria, celts, interpreting, zandvoort,
# Nearest to frac: cdot, functions, undefined, e, definitions, sum, interventional, rc,
# Nearest to recorded: guitarist, howlin, music, discussions, singles, ayurveda, thaw, lindbergh,
# Nearest to experience: travelogue, restriction, revitalization, peer, kampf, osteichthyes, cosines, archdiocese,
# Nearest to gold: irr, load, trapdoor, showdown, satya, rzburg, bormann, aachen,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3293 0.1788 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2785 0.1744 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3402 0.0816 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2420 0.1752 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2517 0.1802 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2289 0.1778 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2348 0.1765 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2432 0.1786 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2102 0.1776 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1743 0.1765 sec/batch
# Nearest to than: microelectronic, solves, diglossia, padding, tines, fundamento, survives, stereocenter,
# Nearest to use: customized, tangible, conformance, impenetrable, computer, mobil, telephony, exchanger,
# Nearest to all: astronomers, tableland, efficiently, bothnia, glycolytic, hutu, burrus, ceiba,
# Nearest to eight: one, five, ecchi, seven, freedesktop, four, adolphe, d,
# Nearest to more: reckoning, forming, humanoid, irreducibility, shoals, menor, compactly, institutions,
# Nearest to after: batman, bloodshed, sanfl, expelled, intervene, parade, hallmark, desire,
# Nearest to used: strangle, steered, sleeker, cocktails, coined, shackles, squid, gwr,
# Nearest to are: nomadic, erosion, and, hellenized, implies, vary, oily, floor,
# Nearest to taking: sassanids, undesirables, tbms, hist, action, adhering, moeller, repealed,
# Nearest to liberal: pedophiles, keir, ironside, illyria, pivotal, contend, share, hurdles,
# Nearest to consists: forested, bicameral, marginal, situated, widest, anoa, subkey, pacific,
# Nearest to bible: encyclopedia, tanakh, geography, liturgical, alexandria, zandvoort, celts, interpreting,
# Nearest to frac: cdot, undefined, functions, sum, hi, interventional, e, definitions,
# Nearest to recorded: music, guitarist, howlin, singles, discussions, ayurveda, thaw, bassist,
# Nearest to experience: restriction, travelogue, peer, kampf, archdiocese, cosines, scientifically, revitalization,
# Nearest to gold: irr, trapdoor, satya, rzburg, aachen, showdown, finely, load,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2442 0.1784 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2209 0.1755 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2178 0.1760 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1365 0.1762 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1643 0.1779 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1778 0.1749 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1632 0.1752 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1755 0.1745 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2159 0.1767 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1809 0.1762 sec/batch
# Nearest to than: microelectronic, solves, padding, diglossia, tines, stereocenter, capita, fundamento,
# Nearest to use: customized, tangible, impenetrable, telephony, mobil, computer, conformance, asbestos,
# Nearest to all: astronomers, efficiently, hutu, tableland, burrus, bothnia, glycolytic, forcibly,
# Nearest to eight: one, five, ecchi, seven, bemba, six, cm, adolphe,
# Nearest to more: reckoning, forming, irreducibility, lamiaceae, humanoid, compactly, shoals, ludo,
# Nearest to after: batman, bloodshed, sanfl, expelled, hallmark, intervene, desire, parade,
# Nearest to used: steered, strangle, sleeker, cocktails, coined, tio, saturation, gwr,
# Nearest to are: nomadic, implies, erosion, and, herbivore, tree, floor, observables,
# Nearest to taking: sassanids, undesirables, tbms, action, hist, adhering, harmoniously, caddies,
# Nearest to liberal: keir, pedophiles, illyria, ironside, contend, share, pivotal, nationalism,
# Nearest to consists: forested, bicameral, widest, marginal, situated, corridors, anoa, subkey,
# Nearest to bible: encyclopedia, tanakh, liturgical, geography, alexandria, celts, interpreting, chabad,
# Nearest to frac: cdot, undefined, functions, sum, e, left, rc, interventional,
# Nearest to recorded: guitarist, music, singles, howlin, bassist, thaw, discussions, ayurveda,
# Nearest to experience: travelogue, restriction, peer, archdiocese, kampf, scientifically, revitalization, cosines,
# Nearest to gold: irr, trapdoor, finely, aachen, satya, load, showdown, bormann,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1591 0.1786 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2469 0.1753 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1858 0.1760 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1371 0.1747 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2092 0.1746 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1722 0.1750 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2059 0.1761 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1629 0.1752 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1331 0.1767 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1824 0.1758 sec/batch
# Nearest to than: microelectronic, capita, solves, padding, stereocenter, transition, diglossia, tines,
# Nearest to use: tangible, customized, impenetrable, telephony, conformance, authority, computer, asbestos,
# Nearest to all: astronomers, efficiently, hutu, exoteric, burrus, bothnia, tableland, glycolytic,
# Nearest to eight: one, five, seven, ecchi, four, six, zero, adolphe,
# Nearest to more: reckoning, humanoid, forming, irreducibility, compactly, lamiaceae, menor, cytosine,
# Nearest to after: batman, sanfl, bloodshed, expelled, hallmark, desire, gip, lotus,
# Nearest to used: steered, strangle, sleeker, coined, tio, shackles, gwr, cocktails,
# Nearest to are: and, implies, nomadic, archiver, khruschev, herbivore, tree, floor,
# Nearest to taking: undesirables, sassanids, tbms, action, hist, adhering, shoreditch, moeller,
# Nearest to liberal: pedophiles, keir, pivotal, ironside, contend, nationalism, illyria, share,
# Nearest to consists: bicameral, forested, anoa, marginal, widest, situated, subkey, corridors,
# Nearest to bible: encyclopedia, tanakh, liturgical, geography, alexandria, testament, celts, nee,
# Nearest to frac: cdot, undefined, e, sum, left, functions, interventional, rc,
# Nearest to recorded: guitarist, music, singles, howlin, genie, bassist, ayurveda, thaw,
# Nearest to experience: travelogue, restriction, peer, kampf, scientifically, revitalization, unwanted, lubin,
# Nearest to gold: irr, finely, satya, trapdoor, aachen, showdown, sulfur, wire,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1827 0.1786 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1651 0.1767 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1899 0.1770 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2118 0.1796 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1766 0.1812 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1343 0.1755 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1621 0.1766 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1382 0.1820 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1789 0.1800 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1956 0.1813 sec/batch
# Nearest to than: microelectronic, capita, solves, padding, survives, tines, diglossia, fundamento,
# Nearest to use: customized, tangible, impenetrable, telephony, conformance, asbestos, authority, optimized,
# Nearest to all: hutu, astronomers, tableland, efficiently, glycolytic, forcibly, ceiba, bothnia,
# Nearest to eight: one, five, seven, four, six, zero, three, adolphe,
# Nearest to more: reckoning, humanoid, forming, compactly, menor, cull, flock, pohnpei,
# Nearest to after: batman, expelled, sanfl, bloodshed, hallmark, warned, intervene, desire,
# Nearest to used: steered, strangle, tio, coined, sleeker, gwr, shackles, cocktails,
# Nearest to are: nomadic, implies, khruschev, archiver, keepers, hellenized, marquesas, floor,
# Nearest to taking: undesirables, sassanids, tbms, shoreditch, action, hist, adhering, moeller,
# Nearest to liberal: pedophiles, keir, pivotal, ironside, contend, ideologically, illyria, share,
# Nearest to consists: bicameral, forested, widest, situated, marginal, anoa, corridors, subkey,
# Nearest to bible: encyclopedia, tanakh, geography, alexandria, liturgical, nee, chabad, zandvoort,
# Nearest to frac: cdot, undefined, e, sum, rc, hi, interventional, left,
# Nearest to recorded: guitarist, music, howlin, singles, thaw, bassist, genie, ayurveda,
# Nearest to experience: travelogue, peer, restriction, lubin, unwanted, kampf, revitalization, gandhi,
# Nearest to gold: irr, finely, aachen, showdown, satya, wire, trapdoor, cubic,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2444 0.1825 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1630 0.1820 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1154 0.1796 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1513 0.1794 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0723 0.1817 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1474 0.1823 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1393 0.1806 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1449 0.1810 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1809 0.0347 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1343 0.1824 sec/batch
# Nearest to than: microelectronic, capita, padding, solves, diglossia, cycles, benefits, tines,
# Nearest to use: customized, tangible, impenetrable, conformance, computer, telephony, norwegian, optimized,
# Nearest to all: efficiently, astronomers, hutu, tableland, bothnia, grs, burrus, glycolytic,
# Nearest to eight: one, five, seven, four, six, zero, adolphe, ecchi,
# Nearest to more: reckoning, humanoid, forming, lamiaceae, vary, compactly, institutions, shoals,
# Nearest to after: batman, bloodshed, sanfl, expelled, warned, hallmark, desire, intervene,
# Nearest to used: steered, tio, strangle, sleeker, shackles, gwr, coined, saturation,
# Nearest to are: and, nomadic, implies, representing, archiver, erosion, codomain, floor,
# Nearest to taking: undesirables, sassanids, tbms, action, shoreditch, adhering, hist, executes,
# Nearest to liberal: pedophiles, keir, petroleum, ironside, pivotal, contend, jak, von,
# Nearest to consists: bicameral, forested, marginal, anoa, widest, corridors, portage, urnfield,
# Nearest to bible: encyclopedia, tanakh, geography, nee, liturgical, alexandria, pronunciations, celts,
# Nearest to frac: cdot, e, sum, left, undefined, rc, hi, functions,
# Nearest to recorded: guitarist, music, bassist, howlin, singles, thaw, genie, tyndall,
# Nearest to experience: restriction, travelogue, unwanted, peer, abominations, kampf, lubin, scientifically,
# Nearest to gold: irr, finely, aachen, satya, bormann, showdown, marta, wire,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0789 0.1839 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0686 0.1809 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0797 0.1796 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0494 0.1806 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0643 0.1809 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0320 0.1795 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0951 0.1804 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0941 0.1801 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1317 0.1808 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0496 0.1810 sec/batch
# Nearest to than: microelectronic, solves, padding, capita, survives, cycles, benefits, fundamento,
# Nearest to use: customized, impenetrable, tangible, norwegian, asbestos, telephony, exchanger, computer,
# Nearest to all: astronomers, efficiently, burrus, hutu, tableland, grs, bothnia, ceiba,
# Nearest to eight: one, five, seven, four, six, zero, three, ecchi,
# Nearest to more: reckoning, humanoid, forming, vary, menor, lamiaceae, compactly, cull,
# Nearest to after: batman, expelled, bloodshed, sanfl, hallmark, warned, intervene, popped,
# Nearest to used: steered, strangle, coined, tio, shackles, disinfectant, saturation, sleeker,
# Nearest to are: nomadic, and, floor, tree, oily, erosion, resemble, inertness,
# Nearest to taking: undesirables, tbms, sassanids, shoreditch, action, harmoniously, clock, moeller,
# Nearest to liberal: pedophiles, keir, petroleum, ironside, pivotal, party, jak, illyria,
# Nearest to consists: bicameral, forested, widest, marginal, anoa, urnfield, ckisch, corridors,
# Nearest to bible: encyclopedia, tanakh, geography, liturgical, chabad, nee, testament, vulgate,
# Nearest to frac: cdot, e, left, sum, undefined, rc, hi, kappa,
# Nearest to recorded: guitarist, music, bassist, howlin, singles, genie, thaw, pipp,
# Nearest to experience: restriction, unwanted, travelogue, peer, scientifically, lubin, kampf, gandhi,
# Nearest to gold: irr, aachen, finely, bormann, bronze, showdown, wire, marta,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0560 0.1846 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0272 0.1806 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0166 0.1798 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0485 0.1800 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0705 0.1806 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0725 0.1807 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0596 0.1818 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1097 0.1811 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0536 0.1809 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0499 0.1813 sec/batch
# Nearest to than: microelectronic, solves, capita, lower, benefits, cycles, padding, survives,
# Nearest to use: customized, impenetrable, tangible, norwegian, asbestos, exchanger, telephony, conformance,
# Nearest to all: hutu, burrus, efficiently, astronomers, tableland, grs, exoteric, neither,
# Nearest to eight: one, five, seven, four, zero, six, three, ecchi,
# Nearest to more: reckoning, humanoid, forming, painstaking, vary, compactly, flexible, lamiaceae,
# Nearest to after: batman, expelled, sanfl, bloodshed, hallmark, desire, warned, gip,
# Nearest to used: steered, tio, disinfectant, strangle, saturation, coined, sleeker, shackles,
# Nearest to are: and, nomadic, implies, tree, oily, floor, herbivore, productivity,
# Nearest to taking: undesirables, tbms, sassanids, shoreditch, action, clock, harmoniously, executes,
# Nearest to liberal: pedophiles, keir, petroleum, jak, pivotal, party, ironside, contend,
# Nearest to consists: bicameral, forested, assembly, marginal, widest, ckisch, anoa, corridors,
# Nearest to bible: encyclopedia, tanakh, geography, nee, liturgical, chabad, pronunciations, testament,
# Nearest to frac: cdot, e, left, sum, kappa, rc, hi, nilpotent,
# Nearest to recorded: guitarist, bassist, music, howlin, genie, singles, thaw, pipp,
# Nearest to experience: unwanted, restriction, travelogue, gandhi, peer, revitalization, malformations, abominations,
# Nearest to gold: irr, finely, aachen, bronze, marta, showdown, bormann, satya,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0673 0.1841 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1037 0.1808 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0974 0.1808 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0521 0.1800 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0663 0.1804 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0808 0.1801 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0577 0.1800 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0754 0.1813 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0837 0.1804 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0835 0.1805 sec/batch
# Nearest to than: microelectronic, capita, solves, lower, benefits, survives, padding, somewhere,
# Nearest to use: customized, impenetrable, norwegian, tangible, conformance, firearms, exchanger, breakdancing,
# Nearest to all: hutu, croquet, neither, tableland, ceiba, discourage, efficiently, forcibly,
# Nearest to eight: one, seven, five, four, six, zero, three, fertility,
# Nearest to more: reckoning, humanoid, forming, vary, compactly, comprehensibility, tz, throughout,
# Nearest to after: expelled, bloodshed, batman, sanfl, ragenfrid, surviving, irene, desire,
# Nearest to used: steered, disinfectant, tio, strangle, shackles, coined, gwr, mace,
# Nearest to are: nomadic, representing, females, and, implies, hellenized, marquesas, khruschev,
# Nearest to taking: undesirables, sassanids, tbms, shoreditch, harmoniously, action, clock, hist,
# Nearest to liberal: pedophiles, keir, petroleum, pivotal, von, jak, ironside, hurdles,
# Nearest to consists: bicameral, forested, anoa, widest, marginal, ckisch, corridors, urnfield,
# Nearest to bible: encyclopedia, tanakh, geography, nee, chabad, liturgical, easton, gog,
# Nearest to frac: cdot, e, left, sum, rc, kappa, cebidae, nilpotent,
# Nearest to recorded: guitarist, bassist, howlin, music, genie, singles, pipp, singer,
# Nearest to experience: restriction, unwanted, travelogue, gandhi, lubin, peer, kampf, credentials,
# Nearest to gold: irr, finely, cubic, bronze, aachen, wire, satya, showdown,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0488 0.1832 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9992 0.1800 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0019 0.1800 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0601 0.1818 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1028 0.1834 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1291 0.1803 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1352 0.1792 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0549 0.1795 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0253 0.1783 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0275 0.1779 sec/batch
# Nearest to than: microelectronic, benefits, capita, solves, lower, somewhere, padding, cycles,
# Nearest to use: customized, impenetrable, norwegian, conformance, optimized, tangible, asbestos, exchanger,
# Nearest to all: hutu, ceiba, efficiently, tableland, croquet, grs, neither, burrus,
# Nearest to eight: one, seven, five, four, six, zero, three, fertility,
# Nearest to more: reckoning, humanoid, forming, venlo, comprehensibility, vary, compactly, ernesto,
# Nearest to after: batman, expelled, sanfl, bloodshed, hallmark, irene, ragenfrid, jail,
# Nearest to used: steered, tio, coined, disinfectant, shackles, strangle, nouns, trollhunters,
# Nearest to are: representing, implies, nomadic, females, and, is, floor, marquesas,
# Nearest to taking: undesirables, sassanids, tbms, shoreditch, clock, executes, action, hist,
# Nearest to liberal: pedophiles, keir, petroleum, pivotal, ironside, jak, hurdles, menger,
# Nearest to consists: bicameral, forested, marginal, anoa, urnfield, widest, assembly, ckisch,
# Nearest to bible: encyclopedia, tanakh, geography, nee, pronunciations, gog, easton, chabad,
# Nearest to frac: cdot, e, left, sum, rc, epsilon, kappa, hi,
# Nearest to recorded: bassist, guitarist, howlin, music, glam, singer, pipp, thaw,
# Nearest to experience: unwanted, restriction, travelogue, lubin, peer, abominations, gandhi, credentials,
# Nearest to gold: irr, cubic, bronze, finely, aachen, marta, troy, wire,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9645 0.1819 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0538 0.1785 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0677 0.1790 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0388 0.1788 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0889 0.1785 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0474 0.1659 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0244 0.1797 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9659 0.1801 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0267 0.1788 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9732 0.1795 sec/batch
# Nearest to than: microelectronic, solves, benefits, survives, transition, lower, somewhere, padding,
# Nearest to use: impenetrable, customized, norwegian, conformance, firearms, asbestos, tangible, exchanger,
# Nearest to all: hutu, tableland, ceiba, neither, astronomers, airshow, caiman, burrus,
# Nearest to eight: one, seven, five, four, six, zero, three, nine,
# Nearest to more: reckoning, humanoid, forming, venlo, vary, throughout, comprehensibility, bedded,
# Nearest to after: expelled, ragenfrid, bloodshed, batman, sanfl, irene, hallmark, surviving,
# Nearest to used: steered, disinfectant, coined, tio, shackles, strangle, nouns, saturation,
# Nearest to are: representing, nomadic, oily, females, floor, implies, allah, keepers,
# Nearest to taking: undesirables, tbms, sassanids, harmoniously, shoreditch, clock, executes, action,
# Nearest to liberal: pedophiles, keir, petroleum, ironside, pivotal, jak, menger, von,
# Nearest to consists: bicameral, forested, anoa, assembly, marginal, urnfield, representatives, puebla,
# Nearest to bible: tanakh, encyclopedia, geography, nee, gog, pronunciations, chabad, liturgical,
# Nearest to frac: cdot, e, left, sum, epsilon, kappa, hi, cebidae,
# Nearest to recorded: bassist, ayurveda, glam, howlin, thaw, music, guitarist, seasonal,
# Nearest to experience: unwanted, restriction, peer, travelogue, gandhi, malformations, credentials, flashbacks,
# Nearest to gold: irr, finely, bronze, cubic, troy, aachen, unnumbered, aid,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0158 0.1819 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9284 0.1796 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9977 0.1795 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0220 0.1794 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0267 0.1793 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9846 0.1795 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9071 0.1792 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9664 0.1801 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9290 0.1786 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9427 0.1792 sec/batch
# Nearest to than: benefits, microelectronic, lower, solves, transition, survives, capita, cycles,
# Nearest to use: impenetrable, customized, firearms, asbestos, norwegian, breakdancing, conformance, microchip,
# Nearest to all: hutu, burrus, grs, neither, ceiba, exoteric, astronomers, tableland,
# Nearest to eight: one, five, four, seven, zero, six, three, fertility,
# Nearest to more: humanoid, reckoning, forming, vary, throughout, bedded, cracks, ernesto,
# Nearest to after: expelled, ragenfrid, batman, bloodshed, hallmark, sanfl, eleven, consecutive,
# Nearest to used: steered, disinfectant, coined, tio, strangle, shackles, saturation, substitute,
# Nearest to are: nomadic, representing, females, oily, resemble, have, tree, implies,
# Nearest to taking: undesirables, tbms, sassanids, harmoniously, shoreditch, clock, hist, moeller,
# Nearest to liberal: pedophiles, keir, jak, petroleum, pivotal, ironside, congregationalism, menger,
# Nearest to consists: bicameral, representatives, assembly, urnfield, forested, anoa, marginal, complexes,
# Nearest to bible: tanakh, encyclopedia, geography, nee, chabad, gog, pronunciations, liturgical,
# Nearest to frac: cdot, left, e, sum, kappa, epsilon, rc, quantized,
# Nearest to recorded: bassist, guitarist, howlin, glam, pipp, singles, music, genie,
# Nearest to experience: unwanted, restriction, gandhi, travelogue, revitalization, credentials, flashbacks, abominations,
# Nearest to gold: irr, bronze, cubic, troy, finely, woven, wire, silver,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9771 0.1832 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9973 0.1788 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9629 0.1783 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9916 0.1788 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0411 0.1788 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9246 0.1791 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0168 0.1807 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9737 0.1789 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0006 0.1799 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0085 0.1802 sec/batch
# Nearest to than: microelectronic, benefits, lower, solves, somewhere, fundamento, capita, transition,
# Nearest to use: customized, impenetrable, conformance, breakdancing, tangible, microchip, telephony, asbestos,
# Nearest to all: hutu, exoteric, burrus, grs, neither, authoritative, cerinthus, discourage,
# Nearest to eight: one, seven, four, five, six, zero, three, nine,
# Nearest to more: reckoning, forming, humanoid, vary, comprehensibility, bedded, painstaking, ernesto,
# Nearest to after: expelled, ragenfrid, batman, hallmark, irene, bloodshed, sanfl, sleng,
# Nearest to used: disinfectant, steered, coined, saturation, tio, strangle, shackles, mace,
# Nearest to are: representing, nomadic, for, implies, do, oily, anarchistic, consider,
# Nearest to taking: undesirables, tbms, sassanids, clock, harmoniously, shoreditch, moeller, pm,
# Nearest to liberal: pedophiles, keir, petroleum, jak, congregationalism, vouchers, sdp, pivotal,
# Nearest to consists: bicameral, assembly, representatives, urnfield, forested, anoa, belmont, complexes,
# Nearest to bible: encyclopedia, tanakh, geography, nee, pronunciations, gog, liturgical, easton,
# Nearest to frac: cdot, e, left, sum, kappa, quantized, epsilon, hi,
# Nearest to recorded: bassist, guitarist, howlin, glam, music, singles, genie, singer,
# Nearest to experience: unwanted, gandhi, travelogue, opportunities, credentials, abominations, revitalization, flashbacks,
# Nearest to gold: irr, bronze, troy, cubic, unnumbered, marta, aid, inconspicuous,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9909 0.1817 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9961 0.1791 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9923 0.1793 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0053 0.1785 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0164 0.1792 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0085 0.1796 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0066 0.1792 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9823 0.1782 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9706 0.1794 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0175 0.1824 sec/batch
# Nearest to than: benefits, microelectronic, lower, capita, fundamento, solves, somewhere, cycles,
# Nearest to use: customized, impenetrable, conformance, breakdancing, tangible, telephony, microchip, norwegian,
# Nearest to all: hutu, exoteric, neither, grs, ceiba, discourage, burrus, glycolytic,
# Nearest to eight: one, seven, four, five, zero, six, three, nine,
# Nearest to more: reckoning, forming, humanoid, comprehensibility, vary, ernesto, throughout, furthermore,
# Nearest to after: ragenfrid, expelled, irene, hallmark, batman, surviving, thucydides, clary,
# Nearest to used: coined, disinfectant, tio, steered, sometimes, shackles, nouns, saturation,
# Nearest to are: representing, for, nomadic, females, is, implies, do, have,
# Nearest to taking: undesirables, tbms, sassanids, clock, harmoniously, shoreditch, executes, moeller,
# Nearest to liberal: pedophiles, keir, congregationalism, vouchers, petroleum, sdp, jak, pivotal,
# Nearest to consists: bicameral, representatives, urnfield, assembly, complexes, forested, belmont, anoa,
# Nearest to bible: encyclopedia, tanakh, geography, nee, pronunciations, gog, easton, provenance,
# Nearest to frac: cdot, e, left, sum, kappa, epsilon, hi, quantized,
# Nearest to recorded: bassist, guitarist, glam, music, howlin, ayurveda, genie, singles,
# ...
# Nearest to eight: one, seven, six, four, zero, five, three, nine,
# Nearest to more: of, than, potency, most, intersystems, including, humanoid, last,
# Nearest to after: most, and, when, he, the, eleven, had, having,
# Nearest to used: sometimes, an, use, disinfectant, coined, term, steered, tio,
# Nearest to are: all, and, for, be, is, have, they, or,
# Nearest to taking: undesirables, subjectively, shoreditch, odp, license, checkpoints, plane, executes,
# Nearest to liberal: ideologically, pedophiles, ldp, keir, congregationalism, socialism, progressive, sdp,
# Nearest to consists: bicameral, composed, part, is, appellate, semicolon, assembly, called,
# Nearest to bible: encyclopedia, tanakh, easton, harpersanfrancisco, gog, pronunciations, testament, geography,
# Nearest to frac: left, e, cdot, epsilon, right, sinc, plotdata, squaring,
# Nearest to recorded: band, late, recording, resumed, glam, recordings, bassist, digit,
# Nearest to experience: sparteca, to, credentials, revitalization, malformations, opportunities, spector, lubin,
# Nearest to gold: irr, silver, troy, medals, bronze, wire, mercenaries, unnumbered,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8322 0.1791 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8319 0.1748 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8478 0.1752 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8404 0.1756 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8551 0.1764 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8780 0.1748 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8655 0.1752 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8562 0.1750 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8901 0.1748 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8705 0.1759 sec/batch
# Nearest to than: significantly, more, less, of, no, have, although, slightly,
# Nearest to use: used, uses, breakdancing, impenetrable, firearms, corvinus, weft, automatic,
# Nearest to all: are, important, neither, subalgebra, also, their, is, from,
# Nearest to eight: one, seven, six, four, zero, five, three, nine,
# Nearest to more: than, of, furthermore, throughout, intersystems, comprehensibility, most, humanoid,
# Nearest to after: and, most, when, he, the, ragenfrid, having, had,
# Nearest to used: sometimes, use, disinfectant, an, term, coined, steered, tio,
# Nearest to are: all, they, and, is, have, for, not, be,
# Nearest to taking: undesirables, shoreditch, subjectively, infty, sassanids, license, odp, executes,
# Nearest to liberal: ideologically, pedophiles, ldp, keir, progressive, congregationalism, democrat, sdp,
# Nearest to consists: bicameral, composed, part, called, is, appellate, semicolon, belmont,
# Nearest to bible: tanakh, encyclopedia, easton, gog, harpersanfrancisco, pronunciations, testament, geography,
# Nearest to frac: left, cdot, e, plotdata, menstruation, right, sinc, epsilon,
# Nearest to recorded: band, late, recording, resumed, glam, bassist, persist, digit,
# Nearest to experience: sparteca, credentials, opportunities, revitalization, lubin, malformations, flashbacks, spector,
# Nearest to gold: irr, silver, medals, troy, metals, mercenaries, bronze, cubic,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8512 0.1776 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8399 0.1753 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8466 0.1755 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8355 0.1745 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8743 0.1763 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8326 0.1767 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9852 0.1765 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8818 0.1748 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8874 0.1756 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8234 0.1749 sec/batch
# Nearest to than: significantly, more, less, have, no, endorses, of, slightly,
# Nearest to use: used, uses, breakdancing, corvinus, impenetrable, weft, automatic, firearms,
# Nearest to all: are, neither, subalgebra, important, such, grs, hutu, also,
# Nearest to eight: one, seven, six, four, zero, five, three, nine,
# Nearest to more: than, of, furthermore, throughout, intersystems, comprehensibility, most, humanoid,
# Nearest to after: most, and, he, when, ragenfrid, had, although, until,
# Nearest to used: sometimes, an, use, disinfectant, coined, term, steered, tio,
# Nearest to are: all, they, is, have, and, for, not, or,
# Nearest to taking: undesirables, shoreditch, subjectively, odp, infty, wieser, tees, executes,
# Nearest to liberal: ideologically, pedophiles, ldp, progressive, congregationalism, keir, jak, democrat,
# Nearest to consists: bicameral, composed, part, called, by, semicolon, is, deadlock,
# Nearest to bible: tanakh, encyclopedia, easton, harpersanfrancisco, gog, pronunciations, schwarzenberg, geography,
# Nearest to frac: left, e, cdot, menstruation, plotdata, recover, proletarian, mandeville,
# Nearest to recorded: band, late, recording, glam, bassist, resumed, recordings, persist,
# Nearest to experience: sparteca, spector, credentials, lubin, malformations, flashbacks, opportunities, revitalization,
# Nearest to gold: irr, silver, troy, medals, metals, mercenaries, bronze, cubic,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7907 0.1763 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8643 0.1742 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7940 0.1752 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8900 0.1755 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8351 0.1747 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8555 0.1746 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8838 0.1003 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8142 0.1747 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8317 0.1753 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8339 0.1754 sec/batch
# Nearest to than: less, significantly, more, no, of, arboreal, have, quite,
# Nearest to use: used, uses, firearms, breakdancing, weft, impenetrable, corvinus, retroviruses,
# Nearest to all: are, neither, is, important, division, also, subalgebra, together,
# Nearest to eight: one, seven, four, six, five, zero, three, nine,
# Nearest to more: than, humanoid, imparts, of, throughout, furthermore, most, many,
# Nearest to after: he, and, most, the, when, to, had, ragenfrid,
# Nearest to used: sometimes, disinfectant, use, an, coined, term, tio, in,
# Nearest to are: all, they, have, is, be, many, or, and,
# Nearest to taking: undesirables, shoreditch, subjectively, tees, executes, odp, jubilant, infty,
# Nearest to liberal: pedophiles, ideologically, progressive, ldp, keir, congregationalism, jak, mutton,
# Nearest to consists: bicameral, composed, called, part, is, consisting, deadlock, semicolon,
# Nearest to bible: encyclopedia, harpersanfrancisco, tanakh, easton, pronunciations, kindred, schwarzenberg, gog,
# Nearest to frac: left, cdot, e, menstruation, plotdata, proletarian, epsilon, remark,
# Nearest to recorded: band, recording, late, resumed, glam, recordings, bassist, persist,
# Nearest to experience: sparteca, credentials, spector, malformations, lubin, information, opportunities, overlaps,
# Nearest to gold: irr, silver, medals, troy, bronze, mercenaries, metals, cubic,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8386 0.1770 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8183 0.1753 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8165 0.1750 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7999 0.1735 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8656 0.1759 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8217 0.1762 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8929 0.1767 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7292 0.1762 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7993 0.1757 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8031 0.1742 sec/batch
# Nearest to than: more, less, of, significantly, no, slightly, have, quite,
# Nearest to use: used, uses, weft, firearms, corvinus, breakdancing, impenetrable, automatic,
# Nearest to all: are, is, important, neither, also, there, such, types,
# Nearest to eight: one, seven, six, four, zero, five, three, two,
# Nearest to more: than, of, many, most, throughout, potency, humanoid, furthermore,
# Nearest to after: most, and, he, when, although, the, eleven, it,
# Nearest to used: sometimes, an, use, disinfectant, coined, term, often, and,
# Nearest to are: all, and, they, is, for, be, not, or,
# Nearest to taking: undesirables, shoreditch, subjectively, infty, odp, jubilant, tees, executes,
# Nearest to liberal: pedophiles, ideologically, progressive, keir, ldp, sdp, democrat, jak,
# Nearest to consists: bicameral, composed, part, by, called, is, consisting, appellate,
# Nearest to bible: encyclopedia, tanakh, harpersanfrancisco, kindred, gog, easton, pronunciations, testament,
# Nearest to frac: left, cdot, e, menstruation, plotdata, proletarian, right, epsilon,
# Nearest to recorded: recording, band, recordings, resumed, persist, bassist, late, glam,
# Nearest to experience: sparteca, lubin, spector, malformations, credentials, information, blotter, flashbacks,
# Nearest to gold: irr, silver, medals, troy, bronze, mercenaries, metals, wire,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7588 0.1780 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8226 0.1747 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8274 0.1751 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8232 0.1751 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8151 0.1740 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9001 0.1749 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8305 0.1751 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8092 0.1823 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8272 0.1740 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8427 0.1749 sec/batch
# Nearest to than: more, less, significantly, of, no, slightly, considerably, only,
# Nearest to use: used, uses, breakdancing, weft, impenetrable, automatic, firearms, corvinus,
# Nearest to all: are, important, is, also, their, such, types, subalgebra,
# Nearest to eight: one, seven, six, four, five, zero, three, nine,
# Nearest to more: than, of, most, throughout, and, many, furthermore, last,
# Nearest to after: most, when, he, and, until, eleven, it, although,
# Nearest to used: sometimes, an, use, coined, term, disinfectant, often, the,
# Nearest to are: all, and, they, for, have, not, is, be,
# Nearest to taking: undesirables, subjectively, shoreditch, infty, odp, tees, jubilant, checkpoints,
# Nearest to liberal: ideologically, progressive, pedophiles, sdp, ldp, democrat, keir, congregationalism,
# Nearest to consists: composed, bicameral, part, called, is, consisting, assembly, by,
# Nearest to bible: encyclopedia, harpersanfrancisco, tanakh, gog, easton, kindred, pronunciations, schwarzenberg,
# Nearest to frac: left, e, cdot, menstruation, plotdata, recover, proletarian, airstrips,
# Nearest to recorded: recording, band, late, resumed, recordings, bassist, persist, glam,
# Nearest to experience: sparteca, information, malformations, lubin, blotter, opportunities, spector, credentials,
# Nearest to gold: irr, silver, medals, troy, bronze, mercenaries, unnumbered, coins,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8501 0.1776 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8462 0.1742 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8213 0.1747 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8449 0.1756 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8768 0.1741 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8585 0.1755 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8156 0.1748 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8537 0.1749 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8348 0.1752 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8471 0.1745 sec/batch
# Nearest to than: more, less, significantly, of, no, slightly, have, quite,
# Nearest to use: used, uses, firearms, weft, automatic, impenetrable, retroviruses, corvinus,
# Nearest to all: are, also, is, important, their, there, neither, only,
# Nearest to eight: one, seven, four, six, zero, five, three, nine,
# Nearest to more: than, of, and, most, many, throughout, furthermore, the,
# Nearest to after: and, most, when, he, until, had, later, the,
# Nearest to used: sometimes, use, an, term, coined, often, disinfectant, the,
# Nearest to are: all, and, they, is, for, or, there, not,
# Nearest to taking: undesirables, subjectively, tees, odp, shoreditch, infty, checkpoints, jubilant,
# Nearest to liberal: ideologically, progressive, pedophiles, sdp, ldp, democrat, congregationalism, mutton,
# Nearest to consists: composed, bicameral, part, called, consisting, by, appellate, twenty,
# Nearest to bible: encyclopedia, tanakh, gog, harpersanfrancisco, easton, kindred, pronunciations, schwarzenberg,
# Nearest to frac: left, e, cdot, remark, menstruation, proletarian, recover, plotdata,
# Nearest to recorded: recording, band, resumed, late, persist, chronicle, recordings, nominates,
# Nearest to experience: sparteca, information, opportunities, malformations, an, credentials, fermenting, spector,
# Nearest to gold: irr, silver, medals, troy, bronze, mercenaries, metals, wire,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8559 0.1785 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8165 0.1767 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9255 0.1755 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9230 0.1752 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8809 0.1739 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8574 0.1754 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7540 0.1737 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8625 0.1739 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7152 0.1747 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8736 0.1756 sec/batch
# Nearest to than: more, significantly, less, no, of, slightly, considerably, have,
# Nearest to use: used, uses, firearms, retroviruses, automatic, weft, corvinus, koruna,
# Nearest to all: are, also, is, there, from, neither, but, types,
# Nearest to eight: one, seven, six, four, zero, five, three, nine,
# Nearest to more: than, of, and, throughout, furthermore, most, many, the,
# Nearest to after: most, and, he, until, when, eleven, clary, later,
# Nearest to used: sometimes, use, an, term, coined, disinfectant, often, tio,
# Nearest to are: all, is, they, have, there, and, not, or,
# Nearest to taking: subjectively, undesirables, tees, odp, infty, shoreditch, executes, license,
# Nearest to liberal: ideologically, progressive, ldp, pedophiles, sdp, democrats, democrat, congregationalism,
# Nearest to consists: bicameral, composed, part, called, by, consisting, is, twenty,
# Nearest to bible: encyclopedia, harpersanfrancisco, tanakh, easton, pronunciations, gog, schwarzenberg, kindred,
# Nearest to frac: left, e, cdot, menstruation, proletarian, recover, remark, plotdata,
# Nearest to recorded: band, recording, late, tremble, glam, persist, recordings, resumed,
# Nearest to experience: sparteca, spector, information, malformations, lubin, credentials, opportunities, archdiocese,
# Nearest to gold: irr, medals, silver, troy, bronze, mercenaries, wire, metals,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8250 0.1775 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8208 0.1758 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
